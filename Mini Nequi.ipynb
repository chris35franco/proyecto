# %% [markdown]
# importante programacion orientada a objetos
#
# 1) mini Nequi
#
# 2) usuario
#
#    registro
#
#    nombre apellido clave
#
#    nos permita ingresar saldo
#    resta
#
#    crear cuenta de ahorro
#
# 3) herencia / poliformismo
#
# 4) minimo dos usuarios
#
# 5) el 8 como va el progreso, para el 14 trabajo completo

# %%
import pickle
import os
import pathlib
class Cuenta():
    accNo = 0
    name = ''
    deposit=0
    type = ''
    
    def crearCuenta(self):
        self.contra=int(input("ingrese su contraseña: "))
        self.accNo= int(input("Ingrese el número de cuenta : "))
        self.name = input("Ingrese el nombre del titular de la cuenta : ")
        self.type = input("Ingrese el tipo de cuenta [A/P] : ")
        self.deposit = int(input("Ingrese la cantidad inicial (> = 20000 para ahorro y> = 1000000 para actual: "))
        print("\n\n\nCuenta creada")
    
    def mostrarCuenta(self):
        print("Su contraseña es: ",self.contra)
        print("Numero de cuenta: ",self.accNo)
        print("nombre del titular de la cuenta: ", self.name)
        print("Tipo de cuenta: ",self.type)
        print("Balance : ",self.deposit)
    
    def modificarCuenta(self):
        print("Número de cuenta : ",self.accNo)
        self.name = input("Modificar el nombre del titular de la cuenta: ")
        self.type = input("Modificar tipo de cuenta: ")
        self.deposit = int(input("Modificar balance: "))
        
    def cantidad_deposito(self,amount):
        self.deposit += amount
    
    def retirarCantidad(self,amount):
        self.deposit -= amount
    
    def report(self):
        print(self.accNo, " ",self.name ," ",self.type," ", self.deposit)
    
    def getAccountNo(self):
        return self.accNo
    def getAcccountHolderName(self):
        return self.name
    def getAccountType(self):
        return self.type
    def getDeposit(self):
        return self.deposit
    

def intro():
    print("\t\t\t\t**********************")
    print("\t\t\t\t       MINI NEQUI")
    print("\t\t\t\t**********************")

    print("Presentado por:")
    print("Cristian camilo franco B.")
    print("Bienvenido a nuestro sistema")
    
    s=input("pulse enter para ingresar al menu")



def wAccount():
    account = Cuenta()
    account.crearCuenta()
    CuentasArchivo(account)

def displayAll():
    file = pathlib.Path("accounts.data")
    if file.exists ():
        infile = open('accounts.data','rb')
        mylist = pickle.load(infile)
        for item in mylist :
            print(item.accNo," ", item.name, " ",item.type, " ",item.deposit )
        infile.close()
    else :
        print("No hay registros que mostrar")
        

def displaySp(num): 
    file = pathlib.Path("accounts.data")
    if file.exists ():
        infile = open('accounts.data','rb')
        mylist = pickle.load(infile)
        infile.close()
        found = False
        for item in mylist :
            if item.accNo == num :
                print("El saldo de su cuenta es de: ",item.deposit)
                found = True
    else :
        print("No hay registros para buscar")
    if not found :
        print("No existe un registro con este número")

def depositar_y_retirar(num1,num2): 
    file = pathlib.Path("accounts.data")
    if file.exists ():
        infile = open('accounts.data','rb')
        mylist = pickle.load(infile)
        infile.close()
        os.remove('accounts.data')
        for item in mylist :
            if item.accNo == num1 :
                if num2 == 1 :
                    amount = int(input("Ingrese la cantidad a depositar: "))
                    item.deposit += amount
                    print("Tu cuenta está actualizada")
                elif num2 == 2 :
                    amount = int(input("Ingrese el monto a retirar: "))
                    if amount <= item.deposit :
                        item.deposit -=amount
                    else :
                        print("No se puede retirar una cantidad mayor a la indicada")
                
    else :
        print("No hay registros para buscar")
    outfile = open('newaccounts.data','wb')
    pickle.dump(mylist, outfile)
    outfile.close()
    os.rename('newaccounts.data', 'accounts.data')

    
def borrarcuenta(num):
    file = pathlib.Path("accounts.data")
    if file.exists ():
        infile = open('accounts.data','rb')
        oldlist = pickle.load(infile)
        infile.close()
        newlist = []
        for item in oldlist :
            if item.accNo != num :
                newlist.append(item)
        os.remove('accounts.data')
        outfile = open('newaccounts.data','wb')
        pickle.dump(newlist, outfile)
        outfile.close()
        os.rename('newaccounts.data', 'accounts.data')
     
def modificarCuenta(num):
    file = pathlib.Path("accounts.data")
    if file.exists ():
        infile = open('accounts.data','rb')
        oldlist = pickle.load(infile)
        infile.close()
        os.remove('accounts.data')
        for item in oldlist :
            if item.accNo == num :
                item.name = input("Ingrese el nombre del titular de la cuenta: ")
                item.type = input("Ingrese el tipo de cuenta: ")
                item.deposit = int(input("Introduce la cantidad: "))
        
        outfile = open('newaccounts.data','wb')
        pickle.dump(oldlist, outfile)
        outfile.close()
        os.rename('newaccounts.data', 'accounts.data')
   

def CuentasArchivo(account) : 
    
    file = pathlib.Path("accounts.data")
    if file.exists ():
        infile = open('accounts.data','rb')
        oldlist = pickle.load(infile)
        oldlist.append(account)
        infile.close()
        os.remove('accounts.data')
    else :
        oldlist = [account]
    outfile = open('newaccounts.data','wb')
    pickle.dump(oldlist, outfile)
    outfile.close()
    os.rename('newaccounts.data', 'accounts.data')
    
        
ch=''
num=0
intro()

while ch != 8:
    
    print("\tMENÚ PRINCIPAL")
    print("\t1. NUEVA CUENTA")
    print("\t2. CANTIDAD A DEPOSITAR")
    print("\t3. CANTIDAD A RETIRAR")
    print("\t4. CONSULTE SU SALDO")
    print("\t5. LISTA DE TODOS LOS TITULARES DE CUENTA")
    print("\t6. BORRAR UNA CUENTA")
    print("\t7. MODIFICAR UNA CUENTA")
    print("\t8. SALIR")
    print("\tSeleccione su opción (1-8) ")
    ch = input()
    
    if ch == '1':
        wAccount()
    elif ch =='2':
        num = int(input("\tIngresa el numero de cuenta: "))
        depositar_y_retirar(num, 1)
    elif ch == '3':
        num = int(input("\tIngresa el numero de cuenta: "))
        depositar_y_retirar(num, 2)
    elif ch == '4':
        num = int(input("\tIngresa el numero de cuenta: "))
        displaySp(num)
    elif ch == '5':
        displayAll();
    elif ch == '6':
        num =int(input("\tIngresa el numero de cuenta: "))
        borrarcuenta(num)
    elif ch == '7':
        num = int(input("\tIngresa el numero de cuenta: "))
        modificarCuenta(num)
    elif ch == '8':
        print("\t😊 Gracias por usar nuestro sistema 😇 ❤️‍🔥 🔥")
        break
    else :
        print("elección inválida")
    
    ch = input("siga pulsando enter para ver el menu: ")
